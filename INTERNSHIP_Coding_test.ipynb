# %%
import numpy as np
import pandas as pd
import re
import nltk

# %%
df=pd.read_csv("PinjobsDS_coupons_ner.csv", names =["Offer details"])
pd.set_option('display.max_colwidth', -1)
# Out:
# C:\Users\Deepika.Agrawal\anaconda3\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: Passing a negative integer is deprecated in version 1.0 and will not be supported in future version. Instead, use None to not limit the column width.

# %%
display(df)
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                             Offer details
# 0    Save $2.00 ONE Downy Liquid Fabric Conditioner 72 ld or larger (includes Downy Odor Protect 48 oz or larger OR Downy Wrinkle Guard 40 oz or larger OR Downy Nature Blends 67 oz or larger) OR Bounce/Downy Sheets 130 ct or larger (includes Bounce/Downy Wrinkle Guard 80 ct or larger) OR In Wash Scent Boosters 8.6 oz or larger (includes Downy Unstopables, Fresh Protect, Odor Protect, and Infusions) (excludes Downy Libre Enjuague, Gain Fireworks, and trial/travel size).
# 1    Save $2.00 ONE Tide PODS OR Tide Power PODS (excludes Tide Liquid/Powder Laundry Detergent, Tide Simply, Tide Simply PODS, and Tide PODS 9 ct and below, and trial/travel size).
# 2    Save $2.00 ONE Tide Laundry Detergent (excludes Tide Purclean Laundry Detergent, Studio by Tide Laundry Detergent, Tide PODS, Tide Rescue, Tide Simply Laundry Detergent, Tide Simply PODS, Tide Detergent 10 oz and trial/travel size).
# 3    SAVE $1.00 ON TWO when you buy TWO BOXES (8.9 - 15.2 OZ. EXCLUDES LARGE SIZE) any flavor/variety General Mills cereal listed: *
# 4    $3.00 OFF when you purchase any THREE (3) Pepperidge Farm® Farmhouse buns, bread, or cookies
# ..                                                                                            ...
# 881  SAVE $2.00 when you buy $7 worth of participating REESE’S brand candy
# 882  SAVE $5.00 on any Gain scented purchase of $30 or more
# 883  SAVE $1.00 when you buy any ONE (1) NEW AXE product
# 884  BUY TWO GET ONE Buy ONE (1) CHIPS AHOY! Cookies (9.5-19.5 oz.) and ONE (1) SOUR PATCH KIDS Candy (4 oz. or larger), get ONE (1) SOUR PATCH KIDS CHIPS AHOY! Cookies FREE (8 oz.;)
# 885  SAVE $2.00 when you spend $6 on all Suave® products
#
# [886 rows x 1 columns]

# %% [markdown]
# ### Excercise 1
# #### Write a function that takes OfferDetails as input, and returns FaceValue as output

# %%
def get_FaceValue(string_S):   
    y = 'NO _Valu'
    if re.findall('¢',string_S) or re.findall('\$',string_S): # Finding the element which contain dollar or cent symbol 
        for x in string_S.split():
            if ('$' in x) or ('¢'in x): 
                return x
    else:
        return np.nan # Return the Fave Value

# %%
# Check the function functionality 
print(get_FaceValue(df[4:5].to_string()))
print(get_FaceValue(df[880:881].to_string()))
# Out:
# $3.00
# nan

# %% [markdown]
# #### Run the function against all rows in the attached data and determine function accuracy (Higher the better)

# %%
for x in range(1,df.size+1):
    #get_FaceValue(df[:x].to_string())
    print(x,get_FaceValue(df[x-1:x].to_string()))
# Out:
# 1 $2.00
# 2 $2.00
# 3 $2.00
# 4 $1.00
# 5 $3.00
# 6 $1.11
# 7 $1.00
# 8 $1.00
# 9 $0.65
# 10 $2.00
# 11 $0.50
# 12 $1.00
# 13 $0.50
# 14 $0.50
# 15 $1.00
# 16 $1.00
# 17 $1.00
# 18 $0.50
# 19 $2.00
# 20 $0.50
# 21 $1.00
# 22 $1.25
# 23 $2.00
# 24 $1.00
# 25 $1.00
# 26 $1.00
# 27 $1.00
# 28 $1.00
# 29 $1.00
# 30 $1.00
# 31 $1.00
# 32 $1.00
# 33 $0.75
# 34 $1.00
# 35 $3.00
# 36 $2.00
# 37 $4.00
# 38 $2.00
# 39 55¢
# 40 $1.50
# 41 $4.00
# 42 $3.00
# 43 $2.00
# 44 $4.00
# 45 $2.00
# 46 $2.00
# 47 $2.00
# 48 $5.00
# 49 $2.00
# 50 $3.00
# 51 $2.00
# 52 $2.00
# 53 $1.50
# 54 $1.50
# 55 $2.00
# 56 $3.00
# 57 $3.00
# 58 $2.00
# 59 $1.00
# 60 $8.00
# 61 $3.00
# 62 $0.75
# 63 $1.50
# 64 $3.00
# 65 55¢
# 66 $5.00
# 67 $3.00
# 68 $0.75
# 69 $3.00
# 70 $1.00
# 71 $5.00
# 72 $5.00
# 73 $4.00
# 74 $1.00
# 75 $4.00
# 76 $1.00
# 77 $2.00
# 78 $0.75
# 79 $4.00
# 80 $3.00
# 81 $2.00
# 82 $5
# 83 $1.00
# 84 $0.50
# 85 $1.50)
# 86 $1.00
# 87 $1.00
# 88 $2.00
# 89 $2.00
# 90 $1.00
# 91 $2.00
# 92 $0.50
# 93 $0.50
# 94 $0.50
# 95 $1.00
# 96 $2.00
# 97 $2.00
# 98 $1.50
# 99 $1.00
# 100 $2.00
# 101 $2.00
# 102 $1.00
# 103 $1.25
# 104 $1.00
# 105 $1.00
# 106 $0.50
# 107 $0.25
# 108 $1.00
# 109 $1.00
# 110 $2.00
# 111 $1.00
# 112 $1.00
# 113 $2.00
# 114 $3.00
# 115 $0.50
# 116 $2.00
# 117 $1.00
# 118 $1.00
# 119 55¢
# 120 $3.00
# 121 $2.00
# 122 $1.00
# 123 $4.00
# 124 $2.00
# 125 $3.00
# 126 $3.00
# 127 $2.00
# 128 $0.75
# 129 $4.00
# 130 $4.00
# 131 $2.00
# 132 nan
# 133 $4.00
# 134 $4.00
# 135 $2.00
# 136 $5.00
# 137 $1.50
# 138 $5.00
# 139 $3.00
# 140 $4.00
# 141 $3.00
# 142 $3.00
# 143 $5.00
# 144 $3.00
# 145 $5.00
# 146 $1
# 147 $1
# 148 $1
# 149 $1
# 150 nan
# 151 nan
# 152 nan
# 153 nan
# 154 nan
# 155 nan
# 156 nan
# 157 nan
# 158 $1
# 159 $100
# 160 nan
# 161 nan
# 162 nan
# 163 nan
# 164 nan
# 165 nan
# 166 nan
# 167 nan
# 168 nan
# 169 nan
# 170 nan
# 171 nan
# 172 nan
# 173 nan
# 174 nan
# 175 nan
# 176 nan
# 177 nan
# 178 nan
# 179 nan
# 180 nan
# 181 nan
# 182 nan
# 183 nan
# 184 nan
# 185 nan
# 186 nan
# 187 nan
# 188 nan
# 189 nan
# 190 nan
# 191 nan
# 192 nan
# 193 nan
# 194 nan
# 195 nan
# 196 nan
# 197 nan
# 198 nan
# 199 nan
# 200 nan
# 201 nan
# 202 nan
# 203 nan
# 204 nan
# 205 nan
# 206 nan
# 207 nan
# 208 nan
# 209 nan
# 210 nan
# 211 nan
# 212 nan
# 213 nan
# 214 nan
# 215 $3
# 216 $12
# 217 nan
# 218 nan
# 219 nan
# 220 $2
# 221 nan
# 222 $10
# 223 nan
# 224 nan
# 225 $1
# 226 nan
# 227 $2
# 228 nan
# 229 nan
# 230 nan
# 231 nan
# 232 nan
# 233 nan
# 234 nan
# 235 $1
# 236 nan
# 237 nan
# 238 nan
# 239 nan
# 240 nan
# 241 nan
# 242 $1
# 243 nan
# 244 nan
# 245 nan
# 246 nan
# 247 nan
# 248 nan
# 249 nan
# 250 nan
# 251 $5.00
# 252 nan
# 253 nan
# 254 nan
# 255 nan
# 256 nan
# 257 nan
# 258 nan
# 259 nan
# 260 nan
# 261 nan
# 262 nan
# 263 nan
# 264 $2.00
# 265 $3.00
# 266 nan
# 267 nan
# 268 nan
# 269 nan
# 270 nan
# 271 nan
# 272 nan
# 273 nan
# 274 nan
# 275 nan
# 276 nan
# 277 nan
# 278 nan
# 279 nan
# 280 nan
# 281 nan
# 282 nan
# 283 nan
# 284 nan
# 285 nan
# 286 nan
# 287 nan
# 288 nan
# 289 nan
# 290 nan
# 291 nan
# 292 nan
# 293 nan
# 294 nan
# 295 nan
# 296 nan
# 297 nan
# 298 nan
# 299 nan
# 300 nan
# 301 nan
# 302 nan
# 303 nan
# 304 nan
# 305 nan
# 306 nan
# 307 nan
# 308 nan
# 309 nan
# 310 nan
# 311 nan
# 312 nan
# 313 nan
# 314 nan
# 315 nan
# 316 nan
# 317 nan
# 318 nan
# 319 nan
# 320 nan
# 321 nan
# 322 nan
# 323 nan
# 324 nan
# 325 nan
# 326 nan
# 327 nan
# 328 nan
# 329 nan
# 330 nan
# 331 nan
# 332 nan
# 333 nan
# 334 nan
# 335 nan
# 336 nan
# 337 nan
# 338 nan
# 339 nan
# 340 nan
# 341 nan
# 342 nan
# 343 nan
# 344 nan
# 345 nan
# 346 nan
# 347 nan
# 348 nan
# 349 nan
# 350 nan
# 351 nan
# 352 nan
# 353 nan
# 354 nan
# 355 nan
# 356 nan
# 357 nan
# 358 nan
# 359 nan
# 360 nan
# 361 nan
# 362 nan
# 363 nan
# 364 $0.89)
# 365 nan
# 366 nan
# 367 nan
# 368 nan
# 369 nan
# 370 nan
# 371 nan
# 372 nan
# 373 nan
# 374 nan
# 375 nan
# 376 nan
# 377 nan
# 378 nan
# 379 nan
# 380 nan
# 381 nan
# 382 nan
# 383 nan
# 384 nan
# 385 nan
# 386 nan
# 387 nan
# 388 nan
# 389 nan
# 390 nan
# 391 nan
# 392 nan
# 393 nan
# 394 nan
# 395 nan
# 396 nan
# 397 nan
# 398 nan
# 399 nan
# 400 nan
# 401 nan
# 402 nan
# 403 nan
# 404 nan
# 405 nan
# 406 nan
# 407 nan
# 408 nan
# 409 nan
# 410 nan
# 411 nan
# 412 nan
# 413 nan
# 414 nan
# 415 nan
# 416 nan
# 417 nan
# 418 nan
# 419 nan
# 420 nan
# 421 nan
# 422 nan
# 423 $1.00
# 424 $0.40
# 425 $1.50
# 426 $1.00
# 427 $1.00
# 428 nan
# 429 $1.00
# 430 $1.00
# 431 $1.50
# 432 $0.50
# 433 $0.20
# 434 $1.00
# 435 $0.50
# 436 $0.50
# 437 $1.50
# 438 $1.00
# 439 $2.00
# 440 $1.00
# 441 $0.50
# 442 $1.00
# 443 $1.00
# 444 $1.00
# 445 $2.00
# 446 $1.00
# 447 $3.00
# 448 $0.50
# 449 $1.00
# 450 $0.50
# 451 $3.00
# 452 $2.00
# 453 nan
# 454 $25,
# 455 nan
# 456 $1.00
# 457 $2.00
# 458 $1.00
# 459 $0.40
# 460 $2.00
# 461 $1.00
# 462 $2.00
# 463 $2.00
# 464 $0.80
# 465 $0.50
# 466 $1.00
# 467 $1.00
# 468 $4.00
# 469 $2.00
# 470 $2.00
# 471 $1.00
# 472 $1.50
# 473 $2.00
# 474 $0.65
# 475 $1.00
# 476 $2.00
# 477 $3.00
# 478 $2.00
# 479 $3.00
# 480 $0.50
# 481 $1.50
# 482 $1.00
# 483 $0.75
# 484 $3.00
# 485 $2.00
# 486 $1.00
# 487 $1.25
# 488 $3.00
# 489 $2.00
# 490 $0.40
# 491 $1.00
# 492 $1.00
# 493 $0.30
# 494 $2.00
# 495 $2.00
# 496 $1.50
# 497 $1.50
# 498 $2.00
# 499 $1.50
# 500 $3.00
# 501 $3.00
# 502 $3.00
# 503 $3.00
# 504 $.50
# 505 $0.40
# 506 $0.50
# 507 $3.00
# 508 $1.00
# 509 $0.50
# 510 $1.00
# 511 nan
# 512 $2.00
# 513 $2.00
# 514 $.50
# 515 $3.00
# 516 $5.00
# 517 $5.00
# 518 $1.00
# 519 $0.50
# 520 $1.00
# 521 $5.00
# 522 $8.00
# 523 $1.00
# 524 $4.00
# 525 $1.50
# 526 $3.00
# 527 $1.00
# 528 $3.00
# 529 $1.00
# 530 $2.00
# 531 $0.70
# 532 $15.00
# 533 $5.00
# 534 $1.00
# 535 $.50
# 536 $1.00
# 537 $0.75
# 538 $10.00
# 539 $2.00
# 540 $0.75
# 541 $3.00
# 542 $0.50
# 543 $.50
# 544 $4.00
# 545 $4.00
# 546 $1.50
# 547 $0.50
# 548 $1.25
# 549 $2.00
# 550 $3.00
# 551 $1.00
# 552 $1.00
# 553 $0.50
# 554 $1.50
# 555 nan
# 556 $3.00
# 557 $1.00
# 558 $1
# 559 $1.00
# 560 $5.00
# 561 $1.50
# 562 $2.00
# 563 $4.00
# 564 $1.00
# 565 $5.00
# 566 $3.00
# 567 nan
# 568 $2.00
# 569 nan
# 570 $0.50
# 571 $1.00
# 572 $0.30
# 573 $0.55
# 574 $0.75
# 575 $3.00
# 576 $3.00
# 577 $1.00
# 578 nan
# 579 $10.00
# 580 $1.00
# 581 $2.00
# 582 $2.00
# 583 $0.55
# 584 $3.00
# 585 $1.00
# 586 $1.00
# 587 $1.50
# 588 $1.00
# 589 $1.00
# 590 $1.50
# 591 $1.00
# 592 $2.00
# 593 $1.50
# 594 $2.00
# 595 $1.00
# 596 $3.00
# 597 $8.00
# 598 $5.00
# 599 $3.00
# 600 $1.00
# 601 $0.75
# 602 $5.00
# 603 $2.00
# 604 $4.00
# 605 $0.75
# 606 $1.00
# 607 nan
# 608 $2.00
# 609 $1.00
# 610 $5.00
# 611 $5.00
# 612 $1.00
# 613 $0.50
# 614 $1.00
# 615 $0.70
# 616 $2.00
# 617 $1.00
# 618 $1.00
# 619 $1.50
# 620 $1.00
# 621 $5.00
# 622 $10.00
# 623 $2.00
# 624 $1.00
# 625 $1.00
# 626 $2.00
# 627 $2.00
# 628 $1.00
# 629 $1.00
# 630 $1.00
# 631 $0.50
# 632 $1.00
# 633 $1.50
# 634 $.75
# 635 $1.00
# 636 $1.00
# 637 $2.00
# 638 $2.00
# 639 $2.00
# 640 $2.00
# 641 $3.00
# 642 $3.00
# 643 $1.00
# 644 $1.00
# 645 $1.00
# 646 $0.25
# 647 $1.00
# 648 $1.00
# 649 $1.00
# 650 $1.00
# 651 $2.00
# 652 $0.40
# 653 nan
# 654 $1.00
# 655 $2.00
# 656 $0.50
# 657 $1.00
# 658 $1.00
# 659 $0.50
# 660 $1.00
# 661 $0.55
# 662 $1.00
# 663 $2.00
# 664 $10
# 665 $2.00
# 666 $1.00
# 667 $1.00
# 668 $2.00
# 669 $2.00
# 670 $1.00
# 671 $1.00
# 672 $1.00
# 673 $0.50
# 674 $1.00
# 675 $1.50
# 676 $.75
# 677 $1.00
# 678 $1.00
# 679 $2.00
# 680 $2.00
# 681 $2.00
# 682 $2.00
# 683 $3.00
# 684 $3.00
# 685 $1.00
# 686 $1.00
# 687 $1.00
# 688 $0.25
# 689 $1.00
# 690 $1.00
# 691 $1.00
# 692 $1.00
# 693 $2.00
# 694 $0.40
# 695 nan
# 696 $1.00
# 697 $2.00
# 698 $0.50
# 699 $1.00
# 700 $1.00
# 701 $0.50
# 702 $1.00
# 703 $0.55
# 704 $1.00
# 705 $2.00
# 706 $2.00
# 707 $3.99
# 708 $2.00
# 709 $5.00
# 710 $3.00
# 711 $3.00
# 712 $2.00
# 713 $4.00
# 714 $2.00
# 715 $2.00
# 716 $1.00
# 717 $1.50
# 718 $2.00
# 719 $0.75
# 720 $2.00
# 721 $5.00
# 722 $2.00
# 723 $3.00
# 724 $1.00
# 725 $2.00
# 726 $1.00
# 727 $4.00
# 728 $2.00
# 729 $4.00
# 730 $2.00
# 731 $3.00
# 732 $5.00
# 733 $2.00
# 734 $1.00
# 735 $1.00
# 736 $3.00
# 737 $2.00
# 738 $1.00
# 739 $4.00
# 740 $2.00
# 741 $2.00
# 742 $1.00
# 743 $0.65
# 744 $3.00
# 745 $5.00
# 746 $5.00
# 747 $5.00
# 748 $8.00
# 749 $5.00
# 750 $8.00
# 751 $1.00
# 752 $1.00
# 753 $0.55
# 754 $1.00
# 755 $1.00
# 756 $1.00
# 757 $1.00
# 758 $1.00
# 759 $5.00
# 760 $1.00
# 761 $1.00
# 762 $1.00
# 763 $0.75
# 764 $1.00
# 765 $.50
# 766 $1.00
# 767 $2.00
# 768 $3.00
# 769 $0.75
# 770 $2.23
# 771 $1.00
# 772 $1.00
# 773 $0.50
# 774 $5.00
# 775 $1.00
# 776 $0.50
# 777 $3.00
# 778 $.50
# 779 $1.00
# 780 $2.00
# 781 $1.00
# 782 $2.00
# 783 $1.00
# 784 $1.50
# 785 $1.50
# 786 $3.00
# 787 $1.00
# 788 $2.00
# 789 $1.00
# 790 $3.00
# 791 $0.40
# 792 $2.00
# 793 $3.00
# 794 $2.00
# 795 $0.50
# 796 $1.00
# 797 $5.00
# 798 $2.00
# 799 $1.00
# 800 $1.00
# 801 $1.00
# 802 $1.00
# 803 $1.00
# 804 $1.00)
# 805 $1.00
# 806 $1.00
# 807 $1.00
# 808 $0.50
# 809 $2.00
# 810 $0.50
# 811 $0.50
# 812 $1.00
# 813 $3.00
# 814 $1.00
# 815 $3.00
# 816 $0.89)
# 817 $0.50
# 818 $1.50)
# 819 $3.00
# 820 $3.00
# 821 $1.00
# 822 $1.00
# 823 $1.00
# 824 $1.00
# 825 $0.50
# 826 $0.50
# 827 $3.00
# 828 $2.00
# 829 $1.00
# 830 $1.00
# 831 $1.00
# 832 75¢
# 833 $0.50
# 834 $2.00
# 835 $1.50
# 836 $1.00
# 837 $2.00
# 838 $1.00
# 839 $1.00
# 840 55¢
# 841 $1.00
# 842 $3.00
# 843 $1.00
# 844 $1.00
# 845 $2.00
# 846 $1.00
# 847 $2.00
# 848 $1.00
# 849 50¢
# 850 $1.00
# 851 $4.00
# 852 $2.00
# 853 $2.00
# 854 $4.00
# 855 $1.00
# 856 55¢
# 857 $2.50
# 858 $1.00
# 859 $5.00
# 860 $3.00
# 861 $5.00
# 862 $4.00
# 863 $3.00
# 864 $0.50
# 865 $1.00
# 866 $3.00
# 867 $0.50
# 868 75¢
# 869 $2.00
# 870 $3.00
# 871 $4.00
# 872 $1.00
# 873 $1.00
# 874 $0.50
# 875 $1.00
# 876 $2.00
# 877 $2.00
# 878 $1.00
# 879 $1.00
# 880 $3.00
# 881 nan
# 882 $2.00
# 883 $5.00
# 884 $1.00
# 885 nan
# 886 $2.00

# %%
df1=df.copy()

# %%
df1['FaceValue']=df['Offer details'].apply(lambda x: get_FaceValue(x))

# %%
df1.head(132)
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                             Offer details  \
# 0    Save $2.00 ONE Downy Liquid Fabric Conditioner 72 ld or larger (includes Downy Odor Protect 48 oz or larger OR Downy Wrinkle Guard 40 oz or larger OR Downy Nature Blends 67 oz or larger) OR Bounce/Downy Sheets 130 ct or larger (includes Bounce/Downy Wrinkle Guard 80 ct or larger) OR In Wash Scent Boosters 8.6 oz or larger (includes Downy Unstopables, Fresh Protect, Odor Protect, and Infusions) (excludes Downy Libre Enjuague, Gain Fireworks, and trial/travel size).
# 1    Save $2.00 ONE Tide PODS OR Tide Power PODS (excludes Tide Liquid/Powder Laundry Detergent, Tide Simply, Tide Simply PODS, and Tide PODS 9 ct and below, and trial/travel size).
# 2    Save $2.00 ONE Tide Laundry Detergent (excludes Tide Purclean Laundry Detergent, Studio by Tide Laundry Detergent, Tide PODS, Tide Rescue, Tide Simply Laundry Detergent, Tide Simply PODS, Tide Detergent 10 oz and trial/travel size).
# 3    SAVE $1.00 ON TWO when you buy TWO BOXES (8.9 - 15.2 OZ. EXCLUDES LARGE SIZE) any flavor/variety General Mills cereal listed: *
# 4    $3.00 OFF when you purchase any THREE (3) Pepperidge Farm® Farmhouse buns, bread, or cookies
# ..                                                                                            ...
# 127  $0.75 OFF any ONE (1) Lily’s Chocolate Bar, Chocolate Candy or Baking Chips
# 128  SAVE $4.00 when you buy ONE (1) Adult ZYRTEC® product, any variety (24-45ct). Excludes trial &amp; travel sizes
# 129  $4.00 OFF on ONE (1) Allegra® Allergy 24ct or larger, Allegra-D®, or Children's Allegra® Product
# 130  SAVE $2.00 ONE Dreft Newborn Laundry Detergent OR Dreft Active Baby Laundry Detergent OR Dreft Pure Gentleness Laundry Detergent (excludes trial/travel size).
# 131  BUY ONE GET ONE FREE on any ONE (1) bag of Flavors of America by Eight O'Clock®, Any variety 11oz.
#
#     FaceValue
# 0    $2.00
# 1    $2.00
# 2    $2.00
# 3    $1.00
# 4    $3.00
# ..     ...
# 127  $0.75
# 128  $4.00
# 129  $4.00
# 130  $2.00
# 131  NaN
#
# [132 rows x 2 columns]

# %%
df1.isnull().sum()
# Out:
# Offer details    0
# FaceValue        273
# dtype: int64

# %% [markdown]
# Accuracy of this function around 95%

# %% [markdown]
# # Exercise 2
#
# ## Write a function that takes OfferDetails as input, and returns PurchaseRequirements output

# %%
pip install -U spacy
# Out:
# Requirement already satisfied: spacy in c:\users\deepika.agrawal\anaconda3\lib\site-packages (2.3.5)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\deepika.agrawal\anaconda3\lib\site-packages (from spacy) (2.0.5)
# Requirement already satisfied: thinc<7.5.0,>=7.4.1 in c:\users\deepika.agrawal\anaconda3\lib\site-packages (from spacy) (7.4.5)
# Requirement already satisfied: setuptools in c:\users\deepika.agrawal\anaconda3\lib\site-packages (from spacy) (52.0.0)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\deepika.agrawal\anaconda3\lib\site-packages (from spacy) (3.0.5)
# Requirement already satisfied: srsly<1.1.0,>=1.0.2 in c:\users\deepika.agrawal\anaconda3\lib\site-packages (from spacy) (1.0.5)
# Requirement already satisfied: catalogue<1.1.0,>=0.0.7 in c:\users\deepika.agrawal\anaconda3\lib\site-packages (from spacy) (1.0.0)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in c:\users\deepika.agrawal\anaconda3\lib\site-packages (from spacy) (0.7.4)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\deepika.agrawal\anaconda3\lib\site-packages (from spacy) (4.54.1)
# Requirement already satisfied: wasabi<1.1.0,>=0.4.0 in c:\users\deepika.agrawal\anaconda3\lib\site-packages (from spacy) (0.8.1)
# Requirement already satisfied: plac<1.2.0,>=0.9.6 in c:\users\deepika.agrawal\anaconda3\lib\site-packages (from spacy) (1.1.3)
# Requirement already satisfied: numpy>=1.15.0 in c:\users\deepika.agrawal\anaconda3\lib\site-packages (from spacy) (1.19.5)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\deepika.agrawal\appdata\roaming\python\python37\site-packages (from spacy) (2.25.1)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\deepika.agrawal\anaconda3\lib\site-packages (from spacy) (1.0.5)
# Requirement already satisfied: importlib-metadata>=0.20 in c:\users\deepika.agrawal\anaconda3\lib\site-packages (from catalogue<1.1.0,>=0.0.7->spacy) (1.5.0)
# Requirement already satisfied: zipp>=0.5 in c:\users\deepika.agrawal\anaconda3\lib\site-packages (from importlib-metadata>=0.20->catalogue<1.1.0,>=0.0.7->spacy) (2.2.0)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\deepika.agrawal\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\deepika.agrawal\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (1.25.8)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\deepika.agrawal\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2019.11.28)
# Requirement already satisfied: chardet<5,>=3.0.2 in c:\users\deepika.agrawal\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.0.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install -U pip setuptools wheel
# Out:
# Requirement already satisfied: pip in c:\users\deepika.agrawal\anaconda3\lib\site-packages (21.0.1)
# Requirement already satisfied: setuptools in c:\users\deepika.agrawal\anaconda3\lib\site-packages (52.0.0)
# Requirement already satisfied: wheel in c:\users\deepika.agrawal\anaconda3\lib\site-packages (0.36.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
import spacy

# %%
from spacy import displacy

# %%
spacy.cli.download("en_core_web_sm")
# Out:
# ✔ Download and installation successful
# You can now load the model via spacy.load('en_core_web_sm')

# %%
nlp = spacy.load('en_core_web_sm')

# %%
str2 = str(df['Offer details'].loc[0])
doc2=nlp(str2)
displacy.render(doc2, style="ent")
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Save $
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2.00
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
#  ONE Downy Liquid Fabric Conditioner
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     72
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  ld or larger (includes
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Downy Odor
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">FAC</span>
# </mark>
#  Protect
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     48
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  oz or larger OR
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Downy Wrinkle Guard
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     40
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  oz or larger OR
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Downy Nature Blends 67
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
#  oz or larger) OR
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bounce/Downy Sheets
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     130
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  ct or larger (includes
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bounce/Downy Wrinkle Guard
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  80 ct or larger) OR In Wash Scent Boosters 8.6 oz or larger (includes
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Downy Unstopables
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , Fresh Protect,
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Odor Protect
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# , and Infusions) (excludes
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Downy Libre Enjuague
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , Gain
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Fireworks
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , and trial/travel size).</div></span>

# %%
str3 = str(df['Offer details'].loc[7])
doc3=nlp(str3)
displacy.render(doc3, style="ent")
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Save $
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1.00
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
#  on any
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     TWO
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  (
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# ) Sargento® Natural Cheese Slices</div></span>

# %%
str4 = str(df['Offer details'].loc[7])
doc4=nlp(str4)
displacy.render(doc4, style="ent")
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Save $
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1.00
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
#  on any
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     TWO
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  (
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# ) Sargento® Natural Cheese Slices</div></span>

# %% [markdown]
# We can notice from the dataset that, we have to buy particular amount/quantity of products to avail the offer i.e. our Purchase Requirement.

# %%
def quantities(doc):
    doc=nlp(doc)
    list2 = []
    for ent in doc.ents:
          if ent.label_ in {'CARDINAL'} :
            list2.append(ent.text)
    return list2

# %%
quantities(str3)
# Out:
# ['TWO', '2']

# %% [markdown]
# ### Run the function against all rows in the attached data and determine function accuracy (Higher the better)

# %%
for x in range(1,df.size+1):
    print(x,quantities(df[x-1:x].to_string()))
# Out:
# 1 ['48', '40', '130']
# 2 ['1', 'ONE']
# 3 ['2']
# 4 ['3', 'TWO', 'TWO', '8.9']
# 5 ['4', 'THREE', '3']
# 6 ['5', 'ONE']
# 7 ['6', 'TWO', 'TWO', '5']
# 8 ['7', 'TWO', '2']
# 9 ['8', 'ONE', '1']
# 10 ['9', '1', 'Eight', '10', '12']
# 11 ['10', 'ONE', '34', '13', '40', '60', '4.3', '50']
# 12 ['11', 'TWO', 'TWO']
# 13 ['12', '1']
# 14 ['13', 'ONE', '1']
# 15 ['14', 'THREE', '3']
# 16 ['15', 'ONE', '1']
# 17 ['16', '12', '26', '9']
# 18 ['17', 'ONE', '1']
# 19 ['18', 'TWO', '2']
# 20 ['19', '1', '40oz+']
# 21 ['20', 'ONE']
# 22 ['21', 'ONE', '1']
# 23 ['22']
# 24 ['23', 'THREE', '3']
# 25 ['24', 'ONE']
# 26 ['25', '32', '25', '44', '5.7', '3']
# 27 ['26', '48', '5.7', '105']
# 28 ['27', 'ONE', '1', '56']
# 29 ['28', 'ONE', '1', '4']
# 30 ['29', 'ONE']
# 31 ['30', 'TWO', '2']
# 32 ['31', 'ONE']
# 33 ['32', 'ONE']
# 34 ['33', 'ONE', '50', '75']
# 35 ['34']
# 36 ['35', '14']
# 37 ['36', '1']
# 38 ['37', 'ONE']
# 39 ['38', '55¢', 'ONE', '1', '2', '2.5']
# 40 ['39', 'ONE', '1']
# 41 ['40', 'ONE']
# 42 ['41', 'ONE']
# 43 ['42', '27']
# 44 ['43', 'ONE', '1']
# 45 ['44', '30', '18']
# 46 ['45', 'ONE']
# 47 ['46', '1', '2X']
# 48 ['47', 'ONE', '1']
# 49 ['48', '8.6']
# 50 ['49', '1']
# 51 ['50', 'ONE']
# 52 ['51', 'ONE']
# 53 ['52', 'ONE', '1']
# 54 ['53', 'ONE', '1', '10']
# 55 ['54', 'ONE']
# 56 ['55', 'ONE', '1']
# 57 ['56', 'ONE', '1', '40']
# 58 ['57']
# 59 ['58', 'ONE', '20']
# 60 ['59']
# 61 ['60', '3.0']
# 62 ['61']
# 63 ['62', 'ONE', '1']
# 64 ['63', 'ONE', '4']
# 65 ['64', '55¢', 'ONE', '1']
# 66 ['65', 'ONE', '1']
# 67 ['66', 'ONE']
# 68 ['67']
# 69 ['68', 'ONE', '1']
# 70 ['69', 'ONE', '1']
# 71 ['70', '1', '™']
# 72 ['71', 'ONE']
# 73 ['72', 'ONE']
# 74 ['73']
# 75 ['74', 'ONE', '4']
# 76 ['75']
# 77 ['76']
# 78 ['77', 'ONE']
# 79 ['78', '4']
# 80 ['79', '2']
# 81 ['80']
# 82 ['81']
# 83 ['82', 'TWO', '2']
# 84 ['83', 'ONE', '1']
# 85 ['84', 'two', '2', '12', 'TWO', '2']
# 86 ['85', 'ONE', '12', '26', '9']
# 87 ['86', 'ONE', '3', '4.6']
# 88 ['87', 'ONE']
# 89 ['88', 'TWO', '2', '13.7']
# 90 ['89', '32', '25', '44', '5.7', '3']
# 91 ['90', 'ONE']
# 92 ['91', 'ONE', '34', '13', '40', '60', '4.3', '50']
# 93 ['92', 'ONE', '1']
# 94 ['93', '1']
# 95 ['94']
# 96 ['95', 'ONE']
# 97 ['96', '14']
# 98 ['97', 'ONE', '1']
# 99 ['98', 'THREE', '3']
# 100 ['99', '72', '48', '40', '130']
# 101 ['100', 'TWO', '2']
# 102 ['101', 'TWO', '2']
# 103 ['102', 'ONE', '1']
# 104 ['103', 'THREE', '3']
# 105 ['104', '48', '5.7', '105']
# 106 ['105', 'one', '1', '40oz+']
# 107 ['106', '1']
# 108 ['107', 'ONE']
# 109 ['108', 'ONE', '1', '4']
# 110 ['109', 'ONE', '27']
# 111 ['110', 'ONE', '1']
# 112 ['111', 'one', '1']
# 113 ['112', 'ONE']
# 114 ['113', 'ONE']
# 115 ['114', 'ONE', '1']
# 116 ['115', 'ONE']
# 117 ['116', 'ONE', '20']
# 118 ['117', 'ONE', '50', '75']
# 119 ['118', '55¢', 'ONE', '1', '2', '2.5']
# 120 ['119', 'ONE']
# 121 ['120', 'ONE']
# 122 ['121', 'ONE']
# 123 ['122', 'ONE', '4']
# 124 ['123', '30', '18']
# 125 ['124', 'ONE', '1', '40']
# 126 ['125', 'ONE']
# 127 ['126', 'ONE']
# 128 ['127', 'ONE']
# 129 ['128', '1']
# 130 ['129', 'ONE', '1']
# 131 ['130']
# 132 ['131', '1', 'Eight', '11']
# 133 ['132', 'ONE']
# 134 ['133', 'ONE']
# 135 ['134']
# 136 ['135', 'ONE', '1']
# 137 ['136', 'ONE', '1', '10']
# 138 ['137', 'ONE', '1']
# 139 ['138', 'ONE', '1']
# 140 ['139', 'ONE', '4']
# 141 ['140', '3.0']
# 142 ['141', 'ONE', '4']
# 143 ['142', '1', '™']
# 144 ['143', 'ONE', '1']
# 145 ['144', 'ONE']
# 146 ['145', '1']
# 147 ['146', '1']
# 148 ['147', '1']
# 149 ['148', '1']
# 150 ['149']
# 151 ['150']
# 152 ['151', '12', '14-oz']
# 153 ['152']
# 154 ['153']
# 155 ['154']
# 156 ['155']
# 157 ['156', '12']
# 158 ['157']
# 159 ['158', '1']
# 160 ['159', '3-ct', '1']
# 161 ['160', '8', '1']
# 162 ['161', '1', 'ONE']
# 163 ['162', '16-oz', '4']
# 164 ['163', '2']
# 165 ['164', '1']
# 166 ['165']
# 167 ['166']
# 168 ['167', '700-ml', '20-oz', '12']
# 169 ['168', '52-oz', '4']
# 170 ['169', '4']
# 171 ['170', '20-oz', '4']
# 172 ['171']
# 173 ['172', '11.15-oz', '4']
# 174 ['173', '4']
# 175 ['174', '12']
# 176 ['175', 'TWO', '2', '15.2']
# 177 ['176', 'TWO', '2', '15.2']
# 178 ['177', 'FIVE', '5']
# 179 ['178', 'THREE', '3']
# 180 ['179', 'ONE', '1']
# 181 ['180', 'ONE', '1']
# 182 ['181', '1']
# 183 ['182', '1']
# 184 ['183']
# 185 ['184', '4']
# 186 ['185', '32-oz', '4']
# 187 ['186']
# 188 ['187']
# 189 ['188', '32-oz']
# 190 ['189', '15-oz']
# 191 ['190', 'ONE', '1']
# 192 ['191', '1']
# 193 ['192', 'TWO', '2']
# 194 ['193', '1']
# 195 ['194', 'ONE', '1']
# 196 ['195', 'THREE', '3']
# 197 ['196', '750-ml', '1.75-ltr', '2']
# 198 ['197', 'TWO', '2']
# 199 ['198', 'TWO', '2']
# 200 ['199', 'TWO', '2']
# 201 ['200', 'FOUR', '4', 'TWO', '1']
# 202 ['201', '18PK', '12PK']
# 203 ['202', 'TWO', '2']
# 204 ['203']
# 205 ['204']
# 206 ['205', 'ONE', '1']
# 207 ['206', '1', 'ONE']
# 208 ['207', '1']
# 209 ['208', 'ONE', '1']
# 210 ['209', '1']
# 211 ['210', 'TWO']
# 212 ['211', 'ONE', '1']
# 213 ['212', '1', '6-Pack']
# 214 ['213', '1']
# 215 ['214', 'THREE', '3', 'SIX', '6']
# 216 ['215', 'SIX', '6', 'THREE']
# 217 ['216', 'ONE', '1']
# 218 ['217', 'TWO', '1']
# 219 ['218', '1']
# 220 ['219', 'TWO', '2', 'FOUR', '4', 'SIX', '6']
# 221 ['220', 'ONE', '1']
# 222 ['221', 'TWO', '2', '1']
# 223 ['222', '1', '1.75']
# 224 ['223', 'TWO', '2', '6pks']
# 225 ['224', '1', 'THREE', '3', 'SIX', '6']
# 226 ['225', 'One', '1']
# 227 ['226', '1', 'TWO', '2']
# 228 ['227', '7', '1', '750', '7']
# 229 ['228', '1']
# 230 ['229']
# 231 ['230', 'ONE', '1']
# 232 ['231', '1']
# 233 ['232', 'ONE', 'ONE', '1']
# 234 ['233']
# 235 ['234', '1', 'THREE', '3', 'SIX', '6']
# 236 ['235', '1', '10PK']
# 237 ['236', '1']
# 238 ['237', '1']
# 239 ['238', '1']
# 240 ['239', '1']
# 241 ['240', '1']
# 242 ['241', '1', 'THREE', '3', 'SIX', '6']
# 243 ['242', '1', '1']
# 244 ['243', '2']
# 245 ['244']
# 246 ['245']
# 247 ['246']
# 248 ['247', '28', '1']
# 249 ['248', '1']
# 250 ['249']
# 251 ['250', '1']
# 252 ['251', 'ONE']
# 253 ['252', 'ONE']
# 254 ['253', 'ONE', '1.4']
# 255 ['254', 'ONE']
# 256 ['255', 'ONE']
# 257 ['256', '16']
# 258 ['257', 'ONE']
# 259 ['258', 'ONE']
# 260 ['259', 'ONE', '3', '4.6']
# 261 ['260', 'ONE']
# 262 ['261', 'ONE']
# 263 ['262', '3.0']
# 264 ['263', '1']
# 265 ['264']
# 266 ['265', '24HR', 'ONE', '1']
# 267 ['266', '1', '4']
# 268 ['267']
# 269 ['268', 'TWO', '2']
# 270 ['269', 'ONE', '1', 'ONE', '60']
# 271 ['270', 'ONE', '1']
# 272 ['271', '1']
# 273 ['272', 'ONE', '1', '4']
# 274 ['273', 'ONE']
# 275 ['274', '1']
# 276 ['275', 'ONE', '4']
# 277 ['276', 'ONE']
# 278 ['277', 'TWO', '2']
# 279 ['278']
# 280 ['279', '1']
# 281 ['280', 'ONE', '1']
# 282 ['281', 'ONE', '1']
# 283 ['282']
# 284 ['283', '12', '2']
# 285 ['284', '1', 'ONE']
# 286 ['285', 'ONE', '37', '50']
# 287 ['286', '16', '12']
# 288 ['287', 'TWO', '2']
# 289 ['288', '16', '14', '12']
# 290 ['289']
# 291 ['290', 'ONE', '1']
# 292 ['291', '1']
# 293 ['292', '1']
# 294 ['293', '1']
# 295 ['294', '1.75-qt']
# 296 ['295']
# 297 ['296']
# 298 ['297', '1']
# 299 ['298', '1']
# 300 ['299', 'TWO', '2', '56']
# 301 ['300', '1']
# 302 ['301', 'ONE', '1']
# 303 ['302']
# 304 ['303']
# 305 ['304']
# 306 ['305']
# 307 ['306']
# 308 ['307', '11.5']
# 309 ['308', '1']
# 310 ['309', '1']
# 311 ['310', '1']
# 312 ['311', 'ONE', '1', '6']
# 313 ['312', 'ONE', '1']
# 314 ['313']
# 315 ['314', '15']
# 316 ['315']
# 317 ['316', '20-oz']
# 318 ['317', '13', '20-oz']
# 319 ['318', '14-oz', '1']
# 320 ['319', '24-oz', '1']
# 321 ['320', '1']
# 322 ['321', 'ONE', '1']
# 323 ['322', 'ONE', '1']
# 324 ['323', '18-oz']
# 325 ['324']
# 326 ['325', '1.05-oz', '1']
# 327 ['326', '5.85']
# 328 ['327', '™', 'FOUR', '1']
# 329 ['328', '™', 'FOUR', '1']
# 330 ['329', '30', '1']
# 331 ['330', '™', '1']
# 332 ['331', '™', '1']
# 333 ['332', 'THREE', '3']
# 334 ['333', 'ONE', '1']
# 335 ['334', 'TWO', '2', '2', '1']
# 336 ['335', 'TWO']
# 337 ['336', '1']
# 338 ['337', '™', 'ONE']
# 339 ['338', 'ONE', '1', '8']
# 340 ['339']
# 341 ['340', '1']
# 342 ['341']
# 343 ['342']
# 344 ['343', '56', '216']
# 345 ['344']
# 346 ['345']
# 347 ['346', '27']
# 348 ['347', '40']
# 349 ['348', '1']
# 350 ['349', 'THREE', '3']
# 351 ['350', 'TWO', '9.5']
# 352 ['351', '3.3']
# 353 ['352', 'ONE', '1', '3']
# 354 ['353', 'ONE', '1', '12']
# 355 ['354', 'TWO']
# 356 ['355', 'ONE', '1']
# 357 ['356', 'TWO', '2']
# 358 ['357', 'ONE', '12', '26', '9']
# 359 ['358', 'ONE']
# 360 ['359', '1']
# 361 ['360', 'ONE', '32', '25', '44', '5.7', '3']
# 362 ['361', 'ONE']
# 363 ['362', 'ONE', '1']
# 364 ['363', 'ONE', '1', '1']
# 365 ['364', '48', '5.7', '105']
# 366 ['365', 'ONE', '72', '48', '40', '130']
# 367 ['366', 'ONE']
# 368 ['367', 'ONE']
# 369 ['368', '1']
# 370 ['369', 'ONE', '1']
# 371 ['370', 'TWO']
# 372 ['371', 'ONE']
# 373 ['372', 'TWO']
# 374 ['373', 'ONE', '34', '13', '40', '60', '4.3', '50']
# 375 ['374', '14']
# 376 ['375', '27']
# 377 ['376', 'ONE', '1']
# 378 ['377', 'ONE', '1']
# 379 ['378', '1', '40oz+']
# 380 ['379', 'ONE', '30', '18']
# 381 ['380', 'ONE', '1', '4']
# 382 ['381', 'ONE']
# 383 ['382', 'ONE', '50', '75']
# 384 ['383', 'ONE']
# 385 ['384', 'ONE']
# 386 ['385', 'ONE']
# 387 ['386', '1']
# 388 ['387', 'ONE']
# 389 ['388', 'ONE']
# 390 ['389', 'ONE']
# 391 ['390', '4']
# 392 ['391', 'ONE', '1', '12']
# 393 ['392', 'ONE']
# 394 ['393', 'ONE']
# 395 ['394', 'THREE', '3']
# 396 ['395', 'ONE']
# 397 ['396', 'ONE']
# 398 ['397', 'ONE']
# 399 ['398', '40']
# 400 ['399']
# 401 ['400', 'ONE', '1']
# 402 ['401', '1']
# 403 ['402', 'ONE']
# 404 ['403', 'ONE']
# 405 ['404']
# 406 ['405', 'ONE', '1']
# 407 ['406', 'ONE', '1', '™']
# 408 ['407', '1']
# 409 ['408', 'ONE', '1', '2', '2.5']
# 410 ['409', 'ONE', '4']
# 411 ['410', 'ONE']
# 412 ['411', 'ONE']
# 413 ['412', 'ONE']
# 414 ['413', '1']
# 415 ['414', 'ONE', '4']
# 416 ['415', 'ONE']
# 417 ['416', 'ONE', '1']
# 418 ['417', 'ONE', '1', '10']
# 419 ['418']
# 420 ['419', '3.0']
# 421 ['420', 'ONE']
# 422 ['421', 'ONE', '1']
# 423 ['422', 'TWO', '2', '8.5']
# 424 ['423', 'ONE', '1']
# 425 ['424', '56']
# 426 ['425', '1']
# 427 ['426', 'TWO', '2']
# 428 ['427', '5.1']
# 429 ['428', 'TWO', '2']
# 430 ['429', 'ONE']
# 431 ['430', 'ONE', '1)Tostitos', '10', 'TWO', '2', '9', '18']
# 432 ['431', '1', '40']
# 433 ['432', 'ONE', '1', '1']
# 434 ['433', 'ONE', '1']
# 435 ['434', 'one', '1']
# 436 ['ONE']
# 437 ['436', 'TWO']
# 438 ['437', 'ONE', '1', '4']
# 439 ['438', 'TWO']
# 440 ['439', 'ONE', '1']
# 441 ['440', '1', '32-oz']
# 442 ['441', 'Three', '3']
# 443 ['442', 'ONE', '3', '4.6']
# 444 ['443', 'ONE', '1']
# 445 ['444', '1']
# 446 ['445', 'THREE', '3']
# 447 ['446', '360']
# 448 ['447', '1', '12-in', '100-ct']
# 449 ['448', 'ONE', '1']
# 450 ['449', 'ONE', '1']
# 451 ['450', 'ONE']
# 452 ['451', '1', '20']
# 453 ['452', '200']
# 454 ['453']
# 455 ['454', '4x']
# 456 ['455', 'TWO', '2']
# 457 ['456', '31']
# 458 ['457']
# 459 ['458', '1']
# 460 ['459', '1']
# 461 ['460', 'TWO', '11']
# 462 ['461', '2', 'TWO', '2']
# 463 ['462', 'TWO']
# 464 ['463']
# 465 ['464', '1', '13']
# 466 ['465', '1', 'ONE', '1', '8']
# 467 ['466', 'TWO']
# 468 ['467', '2', 'TWO', '2', '3.0']
# 469 ['468', 'TWO', '2']
# 470 ['469', '1', '2.7-3', '16', '16', '5']
# 471 ['470', '1']
# 472 ['471', '12', '5']
# 473 ['472', '1']
# 474 ['473', '1']
# 475 ['474', '50', '46']
# 476 ['475', 'ONE', '100']
# 477 ['476', 'ONE', '1', '3.0']
# 478 ['477', '1', '13.5', '2.65', '5']
# 479 ['478', 'ONE', '1', '3.0']
# 480 ['479', '1', '4.4']
# 481 ['480', '1']
# 482 ['481', 'ONE', '1']
# 483 ['482', 'ONE', '1']
# 484 ['483', '1', '3.0']
# 485 ['484']
# 486 ['485', '1', '5']
# 487 ['486', '20-33']
# 488 ['487', '2', 'TWO', '2', '5', '5']
# 489 ['488', '1']
# 490 ['489', '1', '8']
# 491 ['490', '52']
# 492 ['491', '1']
# 493 ['492', '1']
# 494 ['493', '2', 'TWO', '2', '11.7']
# 495 ['494', '2', 'TWO', '2', '2N1']
# 496 ['495', 'ONE', '1', '3.7-5.9']
# 497 ['496', 'ONE', '1', '3.6']
# 498 ['497', 'TWO', '2', '12.1']
# 499 ['498']
# 500 ['499', '2', 'TWO', '2', '26.2']
# 501 ['500', '2', 'TWO', '2', '4.7']
# 502 ['501', '2', 'TWO', '2', '12.1']
# 503 ['502', '2', 'TWO', '2', '29.2']
# 504 ['503', '1', '8']
# 505 ['504', '11']
# 506 ['505', '1']
# 507 ['506', 'TWO', '2', '10.1']
# 508 ['507', '1']
# 509 ['508', '1']
# 510 ['509', 'One', '15']
# 511 ['510', 'ONE', '1']
# 512 ['511', 'Zero', 'ONE', '1', 'Zero', '400']
# 513 ['512', '1']
# 514 ['513', '1']
# 515 ['514', '1']
# 516 ['515', '1', '500']
# 517 ['516', '2', 'TWO', '2', '12']
# 518 ['517', '1', '5']
# 519 ['518', '1', '40']
# 520 ['519', '1', '4']
# 521 ['520', '24']
# 522 ['521', '60', '70']
# 523 ['522', '20']
# 524 ['523', '1']
# 525 ['524']
# 526 ['525', '™', '1', '1', '1']
# 527 ['526', 'ONE', '1.4']
# 528 ['527', 'TWO', '2', '2.65']
# 529 ['528', '1', '2CT']
# 530 ['529', 'ONE', '25CT', '66CT']
# 531 ['530', '1', '8']
# 532 ['531', '1', '5000']
# 533 ['532', '1']
# 534 ['533', '1']
# 535 ['534', '1']
# 536 ['535', 'TWO', '2', '6.5']
# 537 ['536', '1', '10']
# 538 ['537']
# 539 ['538']
# 540 ['539', '1', '9']
# 541 ['540', '1', '1', '2']
# 542 ['541', '1']
# 543 ['542', '1', '6']
# 544 ['543', 'ONE']
# 545 ['544', '1']
# 546 ['545', '1', '10']
# 547 ['546', '1', '5']
# 548 ['547', 'TWO', '2']
# 549 ['548']
# 550 ['549', 'TWO', '9.4']
# 551 ['550', '1']
# 552 ['551', 'one', '1']
# 553 ['552', '1']
# 554 ['553', 'TWO', '2']
# 555 ['554', 'ONE', '1', '2.5', 'ONE', '1']
# 556 ['555', '1']
# 557 ['556', '1', '4505', '2.5']
# 558 ['557', '1']
# 559 ['558', 'ONE']
# 560 ['559', 'ONE', '1']
# 561 ['560', 'TWO', '2', '4.25']
# 562 ['561', '1']
# 563 ['562', '1']
# 564 ['563', '1']
# 565 ['564', '1', '1']
# 566 ['565', '1', '4CT', '5', '4CT']
# 567 ['566', '1', '1']
# 568 ['567', '1']
# 569 ['568', '4', 'ONE']
# 570 ['569', '1']
# 571 ['570', 'TWO', '2', '12', '16']
# 572 ['571', '1', '8']
# 573 ['572', '1', '2', '2.5']
# 574 ['573', '1', '5.3']
# 575 ['574', 'ONE', '1', '4']
# 576 ['575', '1', '1.38']
# 577 ['576', '8.25']
# 578 ['577']
# 579 ['578', 'TWO', '19.5']
# 580 ['579']
# 581 ['580', 'ONE', '1']
# 582 ['581', '1']
# 583 ['582', '1']
# 584 ['583']
# 585 ['584', '2', 'Two', '2']
# 586 ['585', '1']
# 587 ['586', '1']
# 588 ['587', '2']
# 589 ['588', '8.5']
# 590 ['589']
# 591 ['590', '1']
# 592 ['591', '1']
# 593 ['592', '1']
# 594 ['593', 'TWO', '2.6']
# 595 ['594', '1']
# 596 ['595', '1']
# 597 ['596', 'TWO', '2']
# 598 ['597']
# 599 ['598', '1']
# 600 ['599', '1', '8.5']
# 601 ['600', '1', '4.23']
# 602 ['601', '1']
# 603 ['602', 'ONE', '1', '100']
# 604 ['603', '1']
# 605 ['604', '1', '3.5']
# 606 ['605']
# 607 ['606', '2x', '2x']
# 608 ['607', '1']
# 609 ['608', '1', '5.4']
# 610 ['609', '15']
# 611 ['610', '1']
# 612 ['611', '1', '4.5']
# 613 ['612', '1', '8']
# 614 ['613', 'Half', '1']
# 615 ['614', '1', '8']
# 616 ['615', '1', '23', '26']
# 617 ['616']
# 618 ['617', '1', '16']
# 619 ['618', '1', '16']
# 620 ['619', '1']
# 621 ['620', '1']
# 622 ['621']
# 623 ['622', '1', '18']
# 624 ['623']
# 625 ['624', '28']
# 626 ['625', '1']
# 627 ['626', 'ONE', '1', '88']
# 628 ['627', '1', '50', '105']
# 629 ['628', 'ONE', '1', '54']
# 630 ['629']
# 631 ['630', 'ONE']
# 632 ['631', 'TWO']
# 633 ['632', 'ONE', '1', '10']
# 634 []
# 635 ['634', 'ONE', '8.44']
# 636 ['635', 'ONE', '13']
# 637 ['636']
# 638 ['637', '50', '50']
# 639 ['638', '75', '69']
# 640 ['639', 'ONE', '23', '9']
# 641 ['640', '2']
# 642 ['641']
# 643 ['642', '32', '25', '44', '5.7', '3']
# 644 ['643', '5.7']
# 645 ['644', 'ONE', '4']
# 646 ['645']
# 647 ['646', '4']
# 648 ['647', 'ONE']
# 649 ['648', 'ONE', '3', '4.6']
# 650 ['649', 'ONE']
# 651 ['650', '1']
# 652 ['651', 'ONE', '1']
# 653 ['652', '3.0']
# 654 ['653', 'ONE', '1', '1.8', '2']
# 655 ['654', '27']
# 656 ['655', 'one', '1']
# 657 ['656', '9']
# 658 ['657', '48', '5.7', '105', '120']
# 659 ['658', '1', '40']
# 660 ['659', 'ONE', '1', '4']
# 661 ['660', 'ONE', '1', '2', '2.5']
# 662 ['661', 'TWO', '2']
# 663 ['662']
# 664 ['663', 'TWO', '2', '20']
# 665 ['664', '1', '18']
# 666 ['665']
# 667 ['666', '28']
# 668 ['667', '1']
# 669 ['668', 'ONE', '1', '88']
# 670 ['669', 'ONE', '1', '50', '105']
# 671 ['670', 'ONE', '1', '54']
# 672 ['671']
# 673 ['672', 'ONE']
# 674 ['673', 'TWO']
# 675 ['674', 'ONE', '1', '10']
# 676 []
# 677 ['676', 'ONE', '8.44']
# 678 ['677', 'ONE', '13']
# 679 ['678']
# 680 ['679', '50', '50']
# 681 ['680', '75', '69']
# 682 ['681', 'ONE', '23', '9']
# 683 ['682', '2']
# 684 ['683']
# 685 ['684', '32', '25', '44', '5.7', '3']
# 686 ['685', '5.7']
# 687 ['686', 'ONE', '4']
# 688 ['687']
# 689 ['688', '4']
# 690 ['689', 'ONE']
# 691 ['690', 'ONE', '3', '4.6']
# 692 ['691', 'ONE']
# 693 ['692', '1']
# 694 ['693', 'ONE', '1']
# 695 ['694', '3.0']
# 696 ['695', 'ONE', '1', '1.8', '2']
# 697 ['696', '27']
# 698 ['697', 'one', '1']
# 699 ['698', '9']
# 700 ['699', '48', '5.7', '105', '120']
# 701 ['700', '1', '40']
# 702 ['701', 'ONE', '1', '4']
# 703 ['702', 'ONE', '1', '2', '2.5']
# 704 ['703', 'TWO', '2']
# 705 ['704']
# 706 ['705', '1', '60']
# 707 ['706', '1', '5-lb']
# 708 ['707', '1']
# 709 ['708', 'THREE', '3', '16']
# 710 ['709', 'TWO']
# 711 ['710']
# 712 ['711']
# 713 ['712']
# 714 ['713']
# 715 ['714', '1']
# 716 ['715', 'TWO']
# 717 ['716', '360']
# 718 ['717', 'TWO', '2']
# 719 ['718', 'ONE', '1']
# 720 ['719', '1', '14']
# 721 ['720', '1', '500']
# 722 ['721', '40']
# 723 ['722', '1']
# 724 ['723', 'ONE', '1']
# 725 ['724']
# 726 ['725', '4']
# 727 ['726']
# 728 ['727', '105', '120', '60', '3']
# 729 ['728', 'THREE', '3', 'One']
# 730 ['729', '1']
# 731 ['730', 'TWO', '2', '100']
# 732 ['731', '1']
# 733 ['732', '96', '73', '48', '9']
# 734 ['733', 'TWO', '2', '2.4']
# 735 ['734', '1.4']
# 736 ['735', 'ONE']
# 737 ['736']
# 738 ['737', '1']
# 739 ['738', 'TWO', '2']
# 740 ['739', '60', '32', '25', '44', '16.9']
# 741 ['740', '2', 'TWO', '2']
# 742 ['741', 'TWO', '2', '2.85']
# 743 ['742', '1']
# 744 ['743', 'ONE', '1', '4']
# 745 ['744', '24']
# 746 ['745', '15']
# 747 ['746', '24']
# 748 ['747']
# 749 ['748', '1', '8', '20', '30']
# 750 ['749', '60', '70']
# 751 ['750', 'up to 4']
# 752 ['751']
# 753 ['752', '1', '2', '2.5']
# 754 ['753', '1', '16', '50', '16']
# 755 ['754', '44', 'up to 4']
# 756 ['755']
# 757 ['756', '1']
# 758 ['757', '1', '4', '32']
# 759 ['758', '1', 'ONE', '1']
# 760 ['759', '1', '2']
# 761 ['760', '1', '30']
# 762 ['761', 'TWO', '2', '11.15-oz']
# 763 ['762', 'TWO', '2', '16']
# 764 ['763', '1', 'up to 4', '4']
# 765 ['764', 'ONE', '1', '16.9']
# 766 ['765', '1', '48', '105', '120']
# 767 ['766', 'TEN', '10', '20']
# 768 ['767', '1', '3.0']
# 769 ['768', 'ONE']
# 770 ['769', '12', 'THREE', '3']
# 771 ['770', '4']
# 772 ['771', '2.1', 'up to 4', '16']
# 773 ['772', '1', '40']
# 774 ['773', 'ONE', '1']
# 775 ['774', '1', '4']
# 776 ['775', '1']
# 777 ['776', '1', '1', '6', '2', '3', '1', '12', '1', '6']
# 778 ['777', '1', '12.5', '14.75-oz', '4', '4']
# 779 ['778', 'TWO', '2', '8.47', 'up to 4', '8']
# 780 ['779', 'FOUR', '4']
# 781 ['780', '1', '48', 'up to 4', '4']
# 782 ['781', '1', '50-200']
# 783 ['782', '4', '60', '3']
# 784 ['783', '1', '6']
# 785 ['784', 'ONE', '1', '6']
# 786 ['785', '1']
# 787 ['786']
# 788 ['787', '27']
# 789 ['788', '1', '56']
# 790 ['789', '40']
# 791 ['790', '1']
# 792 ['791', '2', 'TWO', '2', '3.5']
# 793 ['792', '1', '™', '3']
# 794 ['793', '1', '200']
# 795 ['794']
# 796 ['795', 'TWO', '2']
# 797 ['796']
# 798 ['797', '10.7']
# 799 ['798', 'ONE', '14', '40']
# 800 ['799', '4']
# 801 ['800', 'THREE', '3']
# 802 ['801', 'ONE', '4']
# 803 ['802']
# 804 ['803', '4', '32', 'ONE', '1', '32']
# 805 ['804', '5.7', '25']
# 806 ['805', 'TWO', '2', '6']
# 807 ['806', 'TWO']
# 808 ['807', '1', '20']
# 809 ['808', 'ONE', '69-75', '40']
# 810 ['809', 'ONE', '1', '42']
# 811 ['810', 'ONE', '1', '52']
# 812 ['811', 'ONE', '34', '10.1']
# 813 ['812', 'ONE']
# 814 ['813', 'ONE', '3', '4.6']
# 815 ['814']
# 816 ['815', '1', '1', '1', '1']
# 817 ['816', 'ONE', '1', '40oz+']
# 818 ['817', 'TWO', 'TWO', '9', '10']
# 819 ['818', '1']
# 820 ['819', 'TWO']
# 821 ['820', 'TWO']
# 822 ['821', 'ONE', 'One']
# 823 ['822', 'ONE', '1', '58']
# 824 ['823', 'TWO', '2']
# 825 ['824', 'ONE', '1']
# 826 ['825', 'ONE']
# 827 ['826', 'TWO', '100']
# 828 ['827', '1', '™']
# 829 ['828', '1', '35']
# 830 ['829', '30']
# 831 ['830', 'TWO', '2', '7.7']
# 832 ['831', '75¢', '1', '16.9', 'one', '1', '128']
# 833 ['832', 'ONE', '1']
# 834 ['833', 'TWO']
# 835 ['834', 'ONE', '1']
# 836 ['835', 'ONE', '1.4']
# 837 ['836']
# 838 ['837', '1', '20/21']
# 839 ['838', 'ONE', '1', '112']
# 840 ['839', '55¢', 'ONE', '1']
# 841 ['840', '1']
# 842 ['841', 'ONE']
# 843 ['842', 'ONE', '1']
# 844 ['843', 'ONE', '16']
# 845 ['844', 'ONE']
# 846 ['845', 'ONE', '1', '12']
# 847 ['846', 'ONE', '27']
# 848 ['847', 'TWO', '2']
# 849 ['848', '50¢', '1', '5.85']
# 850 ['849']
# 851 ['850', 'ONE']
# 852 ['851', 'ONE']
# 853 ['852']
# 854 ['853', '1']
# 855 ['854', 'ONE']
# 856 ['855', '55¢', 'ONE', '1', '2', '2.5']
# 857 ['856', 'ONE', 'ONE']
# 858 ['857', 'ONE', '1', '4']
# 859 ['858', 'ONE', '1']
# 860 ['859', '3.0']
# 861 ['860', 'TWO', 'One']
# 862 ['861', 'ONE', '1']
# 863 ['862', 'ONE', '1']
# 864 ['863', 'ONE', '1']
# 865 ['864', '1']
# 866 ['865', 'ONE', '4']
# 867 ['866', '16']
# 868 ['867', '75¢', '1', '8']
# 869 ['868', 'ONE', '1', '1', '1.8', '2']
# 870 ['869', 'ONE', '1']
# 871 ['870', 'ONE']
# 872 ['871', 'ONE', '1', '22']
# 873 ['872', 'ONE']
# 874 ['873', 'ONE', '1']
# 875 ['874', 'ONE', '1']
# 876 ['875']
# 877 ['876']
# 878 ['877', '1', '28']
# 879 ['878']
# 880 ['879']
# 881 ['880', '1', '4', 'ONE', '1', '20', 'ONE', '1', '20']
# 882 ['881']
# 883 ['882']
# 884 ['883', 'ONE', '1']
# 885 ['884', 'TWO', '1', '9.5', 'ONE', '1', '4', 'ONE', '1', '8']
# 886 ['885']

# %%
df1['Quantities For Offer Redemption']=df1['Offer details'].apply(lambda x: quantities(x))

# %%
df1.head()
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                           Offer details  \
# 0  Save $2.00 ONE Downy Liquid Fabric Conditioner 72 ld or larger (includes Downy Odor Protect 48 oz or larger OR Downy Wrinkle Guard 40 oz or larger OR Downy Nature Blends 67 oz or larger) OR Bounce/Downy Sheets 130 ct or larger (includes Bounce/Downy Wrinkle Guard 80 ct or larger) OR In Wash Scent Boosters 8.6 oz or larger (includes Downy Unstopables, Fresh Protect, Odor Protect, and Infusions) (excludes Downy Libre Enjuague, Gain Fireworks, and trial/travel size).
# 1  Save $2.00 ONE Tide PODS OR Tide Power PODS (excludes Tide Liquid/Powder Laundry Detergent, Tide Simply, Tide Simply PODS, and Tide PODS 9 ct and below, and trial/travel size).
# 2  Save $2.00 ONE Tide Laundry Detergent (excludes Tide Purclean Laundry Detergent, Studio by Tide Laundry Detergent, Tide PODS, Tide Rescue, Tide Simply Laundry Detergent, Tide Simply PODS, Tide Detergent 10 oz and trial/travel size).
# 3  SAVE $1.00 ON TWO when you buy TWO BOXES (8.9 - 15.2 OZ. EXCLUDES LARGE SIZE) any flavor/variety General Mills cereal listed: *
# 4  $3.00 OFF when you purchase any THREE (3) Pepperidge Farm® Farmhouse buns, bread, or cookies
#
#   FaceValue Quantities For Offer Redemption
# 0  $2.00     [72, 48, 40, 130]
# 1  $2.00     [ONE]
# 2  $2.00     [ONE]
# 3  $1.00     [TWO, TWO, 8.9]
# 4  $3.00     [THREE, 3]

# %% [markdown]
# Accuracy for this function is around 80%.

# %%
df1.head()
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                           Offer details  \
# 0  Save $2.00 ONE Downy Liquid Fabric Conditioner 72 ld or larger (includes Downy Odor Protect 48 oz or larger OR Downy Wrinkle Guard 40 oz or larger OR Downy Nature Blends 67 oz or larger) OR Bounce/Downy Sheets 130 ct or larger (includes Bounce/Downy Wrinkle Guard 80 ct or larger) OR In Wash Scent Boosters 8.6 oz or larger (includes Downy Unstopables, Fresh Protect, Odor Protect, and Infusions) (excludes Downy Libre Enjuague, Gain Fireworks, and trial/travel size).
# 1  Save $2.00 ONE Tide PODS OR Tide Power PODS (excludes Tide Liquid/Powder Laundry Detergent, Tide Simply, Tide Simply PODS, and Tide PODS 9 ct and below, and trial/travel size).
# 2  Save $2.00 ONE Tide Laundry Detergent (excludes Tide Purclean Laundry Detergent, Studio by Tide Laundry Detergent, Tide PODS, Tide Rescue, Tide Simply Laundry Detergent, Tide Simply PODS, Tide Detergent 10 oz and trial/travel size).
# 3  SAVE $1.00 ON TWO when you buy TWO BOXES (8.9 - 15.2 OZ. EXCLUDES LARGE SIZE) any flavor/variety General Mills cereal listed: *
# 4  $3.00 OFF when you purchase any THREE (3) Pepperidge Farm® Farmhouse buns, bread, or cookies
#
#   FaceValue Quantities For Offer Redemption
# 0  $2.00     [72, 48, 40, 130]
# 1  $2.00     [ONE]
# 2  $2.00     [ONE]
# 3  $1.00     [TWO, TWO, 8.9]
# 4  $3.00     [THREE, 3]

# %%
df1.to_csv("Exercise 1 & 2.csv", index= False)
