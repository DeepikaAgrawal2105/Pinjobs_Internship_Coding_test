# %%
import numpy as np
import pandas as pd
import re
import nltk

# %%
df=pd.read_csv("PinjobsDS_coupons_ner.csv", names =["Offer details"])
pd.set_option('display.max_colwidth', -1)
# Out:
# C:\Users\Deepika.Agrawal\anaconda3\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: Passing a negative integer is deprecated in version 1.0 and will not be supported in future version. Instead, use None to not limit the column width.

# %%
display(df)
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                             Offer details
# 0    Save $2.00 ONE Downy Liquid Fabric Conditioner 72 ld or larger (includes Downy Odor Protect 48 oz or larger OR Downy Wrinkle Guard 40 oz or larger OR Downy Nature Blends 67 oz or larger) OR Bounce/Downy Sheets 130 ct or larger (includes Bounce/Downy Wrinkle Guard 80 ct or larger) OR In Wash Scent Boosters 8.6 oz or larger (includes Downy Unstopables, Fresh Protect, Odor Protect, and Infusions) (excludes Downy Libre Enjuague, Gain Fireworks, and trial/travel size).
# 1    Save $2.00 ONE Tide PODS OR Tide Power PODS (excludes Tide Liquid/Powder Laundry Detergent, Tide Simply, Tide Simply PODS, and Tide PODS 9 ct and below, and trial/travel size).
# 2    Save $2.00 ONE Tide Laundry Detergent (excludes Tide Purclean Laundry Detergent, Studio by Tide Laundry Detergent, Tide PODS, Tide Rescue, Tide Simply Laundry Detergent, Tide Simply PODS, Tide Detergent 10 oz and trial/travel size).
# 3    SAVE $1.00 ON TWO when you buy TWO BOXES (8.9 - 15.2 OZ. EXCLUDES LARGE SIZE) any flavor/variety General Mills cereal listed: *
# 4    $3.00 OFF when you purchase any THREE (3) Pepperidge Farm® Farmhouse buns, bread, or cookies
# ..                                                                                            ...
# 881  SAVE $2.00 when you buy $7 worth of participating REESE’S brand candy
# 882  SAVE $5.00 on any Gain scented purchase of $30 or more
# 883  SAVE $1.00 when you buy any ONE (1) NEW AXE product
# 884  BUY TWO GET ONE Buy ONE (1) CHIPS AHOY! Cookies (9.5-19.5 oz.) and ONE (1) SOUR PATCH KIDS Candy (4 oz. or larger), get ONE (1) SOUR PATCH KIDS CHIPS AHOY! Cookies FREE (8 oz.;)
# 885  SAVE $2.00 when you spend $6 on all Suave® products
#
# [886 rows x 1 columns]

# %% [markdown]
# ### Excercise 1
# #### Write a function that takes OfferDetails as input, and returns FaceValue as output

# %%
def get_FaceValue(string_S):   
    y = 'NO _Valu'
    if re.findall('¢',string_S) or re.findall('\$',string_S): # Finding the element which contain dollar or cent symbol 
        for x in string_S.split():
            if ('$' in x) or ('¢'in x): 
                return x
    else:
        return np.nan # Return the Fave Value

# %%
# Check the function functionality 
print(get_FaceValue(df[4:5].to_string()))
print(get_FaceValue(df[880:881].to_string()))
# Out:
# $3.00
# nan

# %% [markdown]
# #### Run the function against all rows in the attached data and determine function accuracy (Higher the better)

# %%
for x in range(1,df.size+1):
    #get_FaceValue(df[:x].to_string())
    print(x,get_FaceValue(df[x-1:x].to_string()))
# Out:
# 1 $2.00
# 2 $2.00
# 3 $2.00
# 4 $1.00
# 5 $3.00
# 6 $1.11
# 7 $1.00
# 8 $1.00
# 9 $0.65
# 10 $2.00
# 11 $0.50
# 12 $1.00
# 13 $0.50
# 14 $0.50
# 15 $1.00
# 16 $1.00
# 17 $1.00
# 18 $0.50
# 19 $2.00
# 20 $0.50
# 21 $1.00
# 22 $1.25
# 23 $2.00
# 24 $1.00
# 25 $1.00
# 26 $1.00
# 27 $1.00
# 28 $1.00
# 29 $1.00
# 30 $1.00
# 31 $1.00
# 32 $1.00
# 33 $0.75
# 34 $1.00
# 35 $3.00
# 36 $2.00
# 37 $4.00
# 38 $2.00
# 39 55¢
# 40 $1.50
# 41 $4.00
# 42 $3.00
# 43 $2.00
# 44 $4.00
# 45 $2.00
# 46 $2.00
# 47 $2.00
# 48 $5.00
# 49 $2.00
# 50 $3.00
# 51 $2.00
# 52 $2.00
# 53 $1.50
# 54 $1.50
# 55 $2.00
# 56 $3.00
# 57 $3.00
# 58 $2.00
# 59 $1.00
# 60 $8.00
# 61 $3.00
# 62 $0.75
# 63 $1.50
# 64 $3.00
# 65 55¢
# 66 $5.00
# 67 $3.00
# 68 $0.75
# 69 $3.00
# 70 $1.00
# 71 $5.00
# 72 $5.00
# 73 $4.00
# 74 $1.00
# 75 $4.00
# 76 $1.00
# 77 $2.00
# 78 $0.75
# 79 $4.00
# 80 $3.00
# 81 $2.00
# 82 $5
# 83 $1.00
# 84 $0.50
# 85 $1.50)
# 86 $1.00
# 87 $1.00
# 88 $2.00
# 89 $2.00
# 90 $1.00
# 91 $2.00
# 92 $0.50
# 93 $0.50
# 94 $0.50
# 95 $1.00
# 96 $2.00
# 97 $2.00
# 98 $1.50
# 99 $1.00
# 100 $2.00
# 101 $2.00
# 102 $1.00
# 103 $1.25
# 104 $1.00
# 105 $1.00
# 106 $0.50
# 107 $0.25
# 108 $1.00
# 109 $1.00
# 110 $2.00
# 111 $1.00
# 112 $1.00
# 113 $2.00
# 114 $3.00
# 115 $0.50
# 116 $2.00
# 117 $1.00
# 118 $1.00
# 119 55¢
# 120 $3.00
# 121 $2.00
# 122 $1.00
# 123 $4.00
# 124 $2.00
# 125 $3.00
# 126 $3.00
# 127 $2.00
# 128 $0.75
# 129 $4.00
# 130 $4.00
# 131 $2.00
# 132 nan
# 133 $4.00
# 134 $4.00
# 135 $2.00
# 136 $5.00
# 137 $1.50
# 138 $5.00
# 139 $3.00
# 140 $4.00
# 141 $3.00
# 142 $3.00
# 143 $5.00
# 144 $3.00
# 145 $5.00
# 146 $1
# 147 $1
# 148 $1
# 149 $1
# 150 nan
# 151 nan
# 152 nan
# 153 nan
# 154 nan
# 155 nan
# 156 nan
# 157 nan
# 158 $1
# 159 $100
# 160 nan
# 161 nan
# 162 nan
# 163 nan
# 164 nan
# 165 nan
# 166 nan
# 167 nan
# 168 nan
# 169 nan
# 170 nan
# 171 nan
# 172 nan
# 173 nan
# 174 nan
# 175 nan
# 176 nan
# 177 nan
# 178 nan
# 179 nan
# 180 nan
# 181 nan
# 182 nan
# 183 nan
# 184 nan
# 185 nan
# 186 nan
# 187 nan
# 188 nan
# 189 nan
# 190 nan
# 191 nan
# 192 nan
# 193 nan
# 194 nan
# 195 nan
# 196 nan
# 197 nan
# 198 nan
# 199 nan
# 200 nan
# 201 nan
# 202 nan
# 203 nan
# 204 nan
# 205 nan
# 206 nan
# 207 nan
# 208 nan
# 209 nan
# 210 nan
# 211 nan
# 212 nan
# 213 nan
# 214 nan
# 215 $3
# 216 $12
# 217 nan
# 218 nan
# 219 nan
# 220 $2
# 221 nan
# 222 $10
# 223 nan
# 224 nan
# 225 $1
# 226 nan
# 227 $2
# 228 nan
# 229 nan
# 230 nan
# 231 nan
# 232 nan
# 233 nan
# 234 nan
# 235 $1
# 236 nan
# 237 nan
# 238 nan
# 239 nan
# 240 nan
# 241 nan
# 242 $1
# 243 nan
# 244 nan
# 245 nan
# 246 nan
# 247 nan
# 248 nan
# 249 nan
# 250 nan
# 251 $5.00
# 252 nan
# 253 nan
# 254 nan
# 255 nan
# 256 nan
# 257 nan
# 258 nan
# 259 nan
# 260 nan
# 261 nan
# 262 nan
# 263 nan
# 264 $2.00
# 265 $3.00
# 266 nan
# 267 nan
# 268 nan
# 269 nan
# 270 nan
# 271 nan
# 272 nan
# 273 nan
# 274 nan
# 275 nan
# 276 nan
# 277 nan
# 278 nan
# 279 nan
# 280 nan
# 281 nan
# 282 nan
# 283 nan
# 284 nan
# 285 nan
# 286 nan
# 287 nan
# 288 nan
# 289 nan
# 290 nan
# 291 nan
# 292 nan
# 293 nan
# 294 nan
# 295 nan
# 296 nan
# 297 nan
# 298 nan
# 299 nan
# 300 nan
# 301 nan
# 302 nan
# 303 nan
# 304 nan
# 305 nan
# 306 nan
# 307 nan
# 308 nan
# 309 nan
# 310 nan
# 311 nan
# 312 nan
# 313 nan
# 314 nan
# 315 nan
# 316 nan
# 317 nan
# 318 nan
# 319 nan
# 320 nan
# 321 nan
# 322 nan
# 323 nan
# 324 nan
# 325 nan
# 326 nan
# 327 nan
# 328 nan
# 329 nan
# 330 nan
# 331 nan
# 332 nan
# 333 nan
# 334 nan
# 335 nan
# 336 nan
# 337 nan
# 338 nan
# 339 nan
# 340 nan
# 341 nan
# 342 nan
# 343 nan
# 344 nan
# 345 nan
# 346 nan
# 347 nan
# 348 nan
# 349 nan
# 350 nan
# 351 nan
# 352 nan
# 353 nan
# 354 nan
# 355 nan
# 356 nan
# 357 nan
# 358 nan
# 359 nan
# 360 nan
# 361 nan
# 362 nan
# 363 nan
# 364 $0.89)
# 365 nan
# 366 nan
# 367 nan
# 368 nan
# 369 nan
# 370 nan
# 371 nan
# 372 nan
# 373 nan
# 374 nan
# 375 nan
# 376 nan
# 377 nan
# 378 nan
# 379 nan
# 380 nan
# 381 nan
# 382 nan
# 383 nan
# 384 nan
# 385 nan
# 386 nan
# 387 nan
# 388 nan
# 389 nan
# 390 nan
# 391 nan
# 392 nan
# 393 nan
# 394 nan
# 395 nan
# 396 nan
# 397 nan
# 398 nan
# 399 nan
# 400 nan
# 401 nan
# 402 nan
# 403 nan
# 404 nan
# 405 nan
# 406 nan
# 407 nan
# 408 nan
# 409 nan
# 410 nan
# 411 nan
# 412 nan
# 413 nan
# 414 nan
# 415 nan
# 416 nan
# 417 nan
# 418 nan
# 419 nan
# 420 nan
# 421 nan
# 422 nan
# 423 $1.00
# 424 $0.40
# 425 $1.50
# 426 $1.00
# 427 $1.00
# 428 nan
# 429 $1.00
# 430 $1.00
# 431 $1.50
# 432 $0.50
# 433 $0.20
# 434 $1.00
# 435 $0.50
# 436 $0.50
# 437 $1.50
# 438 $1.00
# 439 $2.00
# 440 $1.00
# 441 $0.50
# 442 $1.00
# 443 $1.00
# 444 $1.00
# 445 $2.00
# 446 $1.00
# 447 $3.00
# 448 $0.50
# 449 $1.00
# 450 $0.50
# 451 $3.00
# 452 $2.00
# 453 nan
# 454 $25,
# 455 nan
# 456 $1.00
# 457 $2.00
# 458 $1.00
# 459 $0.40
# 460 $2.00
# 461 $1.00
# 462 $2.00
# 463 $2.00
# 464 $0.80
# 465 $0.50
# 466 $1.00
# 467 $1.00
# 468 $4.00
# 469 $2.00
# 470 $2.00
# 471 $1.00
# 472 $1.50
# 473 $2.00
# 474 $0.65
# 475 $1.00
# 476 $2.00
# 477 $3.00
# 478 $2.00
# 479 $3.00
# 480 $0.50
# 481 $1.50
# 482 $1.00
# 483 $0.75
# 484 $3.00
# 485 $2.00
# 486 $1.00
# 487 $1.25
# 488 $3.00
# 489 $2.00
# 490 $0.40
# 491 $1.00
# 492 $1.00
# 493 $0.30
# 494 $2.00
# 495 $2.00
# 496 $1.50
# 497 $1.50
# 498 $2.00
# 499 $1.50
# 500 $3.00
# 501 $3.00
# 502 $3.00
# 503 $3.00
# 504 $.50
# 505 $0.40
# 506 $0.50
# 507 $3.00
# 508 $1.00
# 509 $0.50
# 510 $1.00
# 511 nan
# 512 $2.00
# 513 $2.00
# 514 $.50
# 515 $3.00
# 516 $5.00
# 517 $5.00
# 518 $1.00
# 519 $0.50
# 520 $1.00
# 521 $5.00
# 522 $8.00
# 523 $1.00
# 524 $4.00
# 525 $1.50
# 526 $3.00
# 527 $1.00
# 528 $3.00
# 529 $1.00
# 530 $2.00
# 531 $0.70
# 532 $15.00
# 533 $5.00
# 534 $1.00
# 535 $.50
# 536 $1.00
# 537 $0.75
# 538 $10.00
# 539 $2.00
# 540 $0.75
# 541 $3.00
# 542 $0.50
# 543 $.50
# 544 $4.00
# 545 $4.00
# 546 $1.50
# 547 $0.50
# 548 $1.25
# 549 $2.00
# 550 $3.00
# 551 $1.00
# 552 $1.00
# 553 $0.50
# 554 $1.50
# 555 nan
# 556 $3.00
# 557 $1.00
# 558 $1
# 559 $1.00
# 560 $5.00
# 561 $1.50
# 562 $2.00
# 563 $4.00
# 564 $1.00
# 565 $5.00
# 566 $3.00
# 567 nan
# 568 $2.00
# 569 nan
# 570 $0.50
# 571 $1.00
# 572 $0.30
# 573 $0.55
# 574 $0.75
# 575 $3.00
# 576 $3.00
# 577 $1.00
# 578 nan
# 579 $10.00
# 580 $1.00
# 581 $2.00
# 582 $2.00
# 583 $0.55
# 584 $3.00
# 585 $1.00
# 586 $1.00
# 587 $1.50
# 588 $1.00
# 589 $1.00
# 590 $1.50
# 591 $1.00
# 592 $2.00
# 593 $1.50
# 594 $2.00
# 595 $1.00
# 596 $3.00
# 597 $8.00
# 598 $5.00
# 599 $3.00
# 600 $1.00
# 601 $0.75
# 602 $5.00
# 603 $2.00
# 604 $4.00
# 605 $0.75
# 606 $1.00
# 607 nan
# 608 $2.00
# 609 $1.00
# 610 $5.00
# 611 $5.00
# 612 $1.00
# 613 $0.50
# 614 $1.00
# 615 $0.70
# 616 $2.00
# 617 $1.00
# 618 $1.00
# 619 $1.50
# 620 $1.00
# 621 $5.00
# 622 $10.00
# 623 $2.00
# 624 $1.00
# 625 $1.00
# 626 $2.00
# 627 $2.00
# 628 $1.00
# 629 $1.00
# 630 $1.00
# 631 $0.50
# 632 $1.00
# 633 $1.50
# 634 $.75
# 635 $1.00
# 636 $1.00
# 637 $2.00
# 638 $2.00
# 639 $2.00
# 640 $2.00
# 641 $3.00
# 642 $3.00
# 643 $1.00
# 644 $1.00
# 645 $1.00
# 646 $0.25
# 647 $1.00
# 648 $1.00
# 649 $1.00
# 650 $1.00
# 651 $2.00
# 652 $0.40
# 653 nan
# 654 $1.00
# 655 $2.00
# 656 $0.50
# 657 $1.00
# 658 $1.00
# 659 $0.50
# 660 $1.00
# 661 $0.55
# 662 $1.00
# 663 $2.00
# 664 $10
# 665 $2.00
# 666 $1.00
# 667 $1.00
# 668 $2.00
# 669 $2.00
# 670 $1.00
# 671 $1.00
# 672 $1.00
# 673 $0.50
# 674 $1.00
# 675 $1.50
# 676 $.75
# 677 $1.00
# 678 $1.00
# 679 $2.00
# 680 $2.00
# 681 $2.00
# 682 $2.00
# 683 $3.00
# 684 $3.00
# 685 $1.00
# 686 $1.00
# 687 $1.00
# 688 $0.25
# 689 $1.00
# 690 $1.00
# 691 $1.00
# 692 $1.00
# 693 $2.00
# 694 $0.40
# 695 nan
# 696 $1.00
# 697 $2.00
# 698 $0.50
# 699 $1.00
# 700 $1.00
# 701 $0.50
# 702 $1.00
# 703 $0.55
# 704 $1.00
# 705 $2.00
# 706 $2.00
# 707 $3.99
# 708 $2.00
# 709 $5.00
# 710 $3.00
# 711 $3.00
# 712 $2.00
# 713 $4.00
# 714 $2.00
# 715 $2.00
# 716 $1.00
# 717 $1.50
# 718 $2.00
# 719 $0.75
# 720 $2.00
# 721 $5.00
# 722 $2.00
# 723 $3.00
# 724 $1.00
# 725 $2.00
# 726 $1.00
# 727 $4.00
# 728 $2.00
# 729 $4.00
# 730 $2.00
# 731 $3.00
# 732 $5.00
# 733 $2.00
# 734 $1.00
# 735 $1.00
# 736 $3.00
# 737 $2.00
# 738 $1.00
# 739 $4.00
# 740 $2.00
# 741 $2.00
# 742 $1.00
# 743 $0.65
# 744 $3.00
# 745 $5.00
# 746 $5.00
# 747 $5.00
# 748 $8.00
# 749 $5.00
# 750 $8.00
# 751 $1.00
# 752 $1.00
# 753 $0.55
# 754 $1.00
# 755 $1.00
# 756 $1.00
# 757 $1.00
# 758 $1.00
# 759 $5.00
# 760 $1.00
# 761 $1.00
# 762 $1.00
# 763 $0.75
# 764 $1.00
# 765 $.50
# 766 $1.00
# 767 $2.00
# 768 $3.00
# 769 $0.75
# 770 $2.23
# 771 $1.00
# 772 $1.00
# 773 $0.50
# 774 $5.00
# 775 $1.00
# 776 $0.50
# 777 $3.00
# 778 $.50
# 779 $1.00
# 780 $2.00
# 781 $1.00
# 782 $2.00
# 783 $1.00
# 784 $1.50
# 785 $1.50
# 786 $3.00
# 787 $1.00
# 788 $2.00
# 789 $1.00
# 790 $3.00
# 791 $0.40
# 792 $2.00
# 793 $3.00
# 794 $2.00
# 795 $0.50
# 796 $1.00
# 797 $5.00
# 798 $2.00
# 799 $1.00
# 800 $1.00
# 801 $1.00
# 802 $1.00
# 803 $1.00
# 804 $1.00)
# 805 $1.00
# 806 $1.00
# 807 $1.00
# 808 $0.50
# 809 $2.00
# 810 $0.50
# 811 $0.50
# 812 $1.00
# 813 $3.00
# 814 $1.00
# 815 $3.00
# 816 $0.89)
# 817 $0.50
# 818 $1.50)
# 819 $3.00
# 820 $3.00
# 821 $1.00
# 822 $1.00
# 823 $1.00
# 824 $1.00
# 825 $0.50
# 826 $0.50
# 827 $3.00
# 828 $2.00
# 829 $1.00
# 830 $1.00
# 831 $1.00
# 832 75¢
# 833 $0.50
# 834 $2.00
# 835 $1.50
# 836 $1.00
# 837 $2.00
# 838 $1.00
# 839 $1.00
# 840 55¢
# 841 $1.00
# 842 $3.00
# 843 $1.00
# 844 $1.00
# 845 $2.00
# 846 $1.00
# 847 $2.00
# 848 $1.00
# 849 50¢
# 850 $1.00
# 851 $4.00
# 852 $2.00
# 853 $2.00
# 854 $4.00
# 855 $1.00
# 856 55¢
# 857 $2.50
# 858 $1.00
# 859 $5.00
# 860 $3.00
# 861 $5.00
# 862 $4.00
# 863 $3.00
# 864 $0.50
# 865 $1.00
# 866 $3.00
# 867 $0.50
# 868 75¢
# 869 $2.00
# 870 $3.00
# 871 $4.00
# 872 $1.00
# 873 $1.00
# 874 $0.50
# 875 $1.00
# 876 $2.00
# 877 $2.00
# 878 $1.00
# 879 $1.00
# 880 $3.00
# 881 nan
# 882 $2.00
# 883 $5.00
# 884 $1.00
# 885 nan
# 886 $2.00

# %%
df1=df.copy()

# %%
df1['FaceValue']=df['Offer details'].apply(lambda x: get_FaceValue(x))

# %%
df1.head(132)
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                             Offer details  \
# 0    Save $2.00 ONE Downy Liquid Fabric Conditioner 72 ld or larger (includes Downy Odor Protect 48 oz or larger OR Downy Wrinkle Guard 40 oz or larger OR Downy Nature Blends 67 oz or larger) OR Bounce/Downy Sheets 130 ct or larger (includes Bounce/Downy Wrinkle Guard 80 ct or larger) OR In Wash Scent Boosters 8.6 oz or larger (includes Downy Unstopables, Fresh Protect, Odor Protect, and Infusions) (excludes Downy Libre Enjuague, Gain Fireworks, and trial/travel size).
# 1    Save $2.00 ONE Tide PODS OR Tide Power PODS (excludes Tide Liquid/Powder Laundry Detergent, Tide Simply, Tide Simply PODS, and Tide PODS 9 ct and below, and trial/travel size).
# 2    Save $2.00 ONE Tide Laundry Detergent (excludes Tide Purclean Laundry Detergent, Studio by Tide Laundry Detergent, Tide PODS, Tide Rescue, Tide Simply Laundry Detergent, Tide Simply PODS, Tide Detergent 10 oz and trial/travel size).
# 3    SAVE $1.00 ON TWO when you buy TWO BOXES (8.9 - 15.2 OZ. EXCLUDES LARGE SIZE) any flavor/variety General Mills cereal listed: *
# 4    $3.00 OFF when you purchase any THREE (3) Pepperidge Farm® Farmhouse buns, bread, or cookies
# ..                                                                                            ...
# 127  $0.75 OFF any ONE (1) Lily’s Chocolate Bar, Chocolate Candy or Baking Chips
# 128  SAVE $4.00 when you buy ONE (1) Adult ZYRTEC® product, any variety (24-45ct). Excludes trial &amp; travel sizes
# 129  $4.00 OFF on ONE (1) Allegra® Allergy 24ct or larger, Allegra-D®, or Children's Allegra® Product
# 130  SAVE $2.00 ONE Dreft Newborn Laundry Detergent OR Dreft Active Baby Laundry Detergent OR Dreft Pure Gentleness Laundry Detergent (excludes trial/travel size).
# 131  BUY ONE GET ONE FREE on any ONE (1) bag of Flavors of America by Eight O'Clock®, Any variety 11oz.
#
#     FaceValue
# 0    $2.00
# 1    $2.00
# 2    $2.00
# 3    $1.00
# 4    $3.00
# ..     ...
# 127  $0.75
# 128  $4.00
# 129  $4.00
# 130  $2.00
# 131  NaN
#
# [132 rows x 2 columns]

# %%
df1.isnull().sum()
# Out:
# Offer details    0
# FaceValue        273
# dtype: int64

# %% [markdown]
# Accuracy of this function around 95%

# %%
df1.to_csv("Exercise_1.csv", index=False)
